# %% [markdown]
# <div style="
#   display: flex;
#   align-items: center;
#   justify-content: space-between;
#   background: #0b1f3a;
#   padding: 25px;
#   border-radius: 10px;font-family:Arial;
# ">
# <div style="flex: 1; text-align: left;">
#    <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRBY0l-VI-DX6L438bHx0SuE5iSon6zlQ__9Q&s"
#          alt="Sleep Analysis"
#          style="width:300px; border-radius:10px; margin-bottom:16px;">
#   </div>
#   <div style="flex: 1; color: white; text-align: left; padding-left: 30px;">
#     <h1 style="margin: 0; font-size: 28px; line-height: 1.4;">
#       A Data-Driven Analysis of Sleep Patterns, Lifestyle Factors,
#         and Health Impacts in Bangladesh
#     </h1>
#   </div>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding: 25px;
#   border-radius: 10px;font-family:Arial;">
#     <h2 style="color:#2c3e50;">🚀 Project Overview</h2>
#     <p style="font-size:16px; line-height:1.5;">
# This project presents a data-driven analysis of sleep patterns and examines how lifestyle, behavioral, and health-related factors influence sleep quality among individuals in Bangladesh. The study is based on a survey dataset that includes demographic details, sleep schedules, health conditions, and daily habits such as social media usage, work or academic pressure, and stress levels.
#     </p>
#     <p style="font-size:16px; line-height:1.5;">
# The dataset is preprocessed through data cleaning techniques, including handling missing values, standardizing categorical responses, and transforming multi-select variables into analyzable formats. Exploratory Data Analysis (EDA) methods such as univariate, bivariate, and multivariate analysis are applied to uncover patterns and relationships within the data.
#     </p>
#     <p style="font-size:16px; line-height:1.5;">
# The analysis focuses on identifying common reasons for late sleeping, variations in sleep duration, and the impact of poor sleep on health and productivity. The findings aim to provide meaningful insights into sleep behavior and highlight the importance of maintaining healthy sleep habits in modern lifestyles.
# </p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3);  padding: 25px;
#   border-radius: 10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">
# 📝 Project Statement</h2>
#     <p style="font-size:16px; line-height:1.5;">Sleep patterns are closely linked to lifestyle habits and health outcomes, yet limited data-driven insights exist for populations in Bangladesh. This study aims to analyze sleep behavior, identify influencing lifestyle factors, and understand their impact on physical and mental health.</p>

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3);  padding: 25px;
#   border-radius: 10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">🎯 Project Aim</h2>
#     <p style="font-size:16px; line-height:1.5;">
# The aim of this project is to analyze sleep patterns and identify the key lifestyle, behavioral, and health-related factors affecting sleep quality among individuals in Bangladesh using exploratory data analysis (EDA). The study seeks to uncover relationships between sleep habits, daily activities, and health outcomes, and to generate meaningful insights that promote awareness and encourage healthier sleep practices.
# </p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3);  padding: 25px;
#   border-radius: 10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📌 Project Objectives</h2>
# <ul style="font-size:16px; line-height:1.6;">
#         <li>📊 Analyze sleep patterns among individuals</li>
#         <li>🧹 Perform data cleaning and preprocessing</li>
#         <li>🔍 Conduct exploratory data analysis (EDA)</li>
#         <li>📱 Identify key factors contributing to late sleeping</li>
#         <li>😴 Evaluate the health impacts of poor sleep</li>
#         <li>📈 Visualize data using charts and graphs</li>
#         <li>💡 Derive meaningful insights from the dataset</li>
#     </ul>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3);  padding: 25px;
#   border-radius: 10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📂 Dataset Description</h2>
# <ul style="font-size:16px;">
#      <li><b>Dataset Name:</b> Survey Dataset on Sleep Patterns, Health Effects, and Lifestyle Factors in Bangladesh</li>
#      <li>
#   <b>Source URL:</b>
#   <a href="https://data.mendeley.com/datasets/y74tv2jbz3/1">
#     Click here to view dataset
#   </a>
# </li>
# </ul
#  <p style="font-size:16px; line-height:1.5; margin-bottom:10px;">
# <b>The dataset is survey-based and contains a mix of:</b>
# </p>
#     <ul style="font-size:16px; line-height:1.5; margin-top:0;">
#         <li>🔢 <b>Numerical Data:</b> Age, height, weight</li>
#         <li>📂 <b>Categorical Data:</b> Gender, occupation, medical conditions</li>
#         <li>⏰ <b>Time-Based Data:</b> Bedtime and wake-up time</li>
#         <li>🧩 <b>Multi-Select Responses:</b> Reasons for sleeping late</li>
#     </ul>
#  <hr>
#     <h2 style="color:#2c3e50;">📊 Key Features of the Dataset</h2>
#     <ul style="font-size:16px; line-height:1.5;">
#         <li>👥 <b>Demographics:</b> Age range, gender,height,weight,occupation</li>
#         <li>⏰ <b>Sleep Schedule:</b> Bedtime and wake-up time (weekday/weekend)</li>
#         <li>😴 <b>Sleep Quality:</b> Duration and time taken to fall asleep</li>
#         <li>⚠️ <b>Sleep Disturbances:</b> Breathing issues, restlessness,medical conditions</li>
#         <li>📱 <b>Behavioral Factors:</b> Reason for staying up late(Social media, stress, study/work)</li>
#         <li>💡 <b>Health Impacts:</b> Side effect of poor sleep(eg.Fatigue, lack of concentration)</li>
#         <li>☕ <b>Coping Strategies:</b> Methods used to manage sleep deprivation(eg.Caffeine, naps)</li>
#         <li>🏠 <b>Environment:</b> Self-rated Comfort of the sleeping envirorment(1–5 scale)</li>
#     </ul>
# </div>

# %% [markdown]
# <div style="flex: 1; color: white;background-color:#0b1f3a; padding:25px; border-radius:10px;font-family:Arial;">
# <h2>1. Data Loading and Initial Overview</h2>

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3);  padding: 25px;
#   border-radius: 10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">🔹 Importing Libraries</h2>
#  <p style="font-size:16px; line-height:1.5;">
# In any data analysis project using Python, the first step is to import the required libraries. These libraries provide powerful tools for data manipulation, analysis, and visualization. Commonly used libraries include:
# </p>
# <ul style="font-size:16px; line-height:1.5;">
#         <li>Pandas – for data handling and manipulation (DataFrames)</li>
#  <li>NumPy – for numerical computations and array operations</li>
#  <li>Matplotlib,Seaborn and plotly – for data visualization and plotting graphs</li>
# </ul>
# <p style="font-size:16px; line-height:1.5">
# Importing these libraries ensures that all necessary functions are available for efficient data analysis and exploration.
# </p>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">🔹 Loading Dataset</h2>
#  <p style="font-size:16px; line-height:1.5;">
# After importing the required libraries, the next step is to load the dataset into the Python environment. Typically, datasets are stored in formats like CSV, Excel, or JSON.
#  <p style="font-size:16px;line-height:1.5">
# Using Pandas, the dataset can be loaded easily into a DataFrame, which is a tabular structure similar to a spreadsheet.
# </p>
# <p style="font-size:16px;">This step allows us to:</p>
# <ul style="font-size:16px; line-height:1.5;">
# <li>View and understand the structure of the data</li>
# <li>Identify rows, columns, and data types</li>
# <li>Begin preprocessing and cleaning operations</li>
# </ul>
#  <p style="font-size:16px; line-height:1.5;">
# Loading the dataset is a crucial step as it forms the foundation for all further analysis, including data cleaning, visualization, and insight generation.
# </p>
# </div>

# %%
df=pd.read_csv("Survey Dataset on Sleep Patterns, Health Effects, and Lifestyle Factors in Bangladesh.csv")

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">🔹Initial Overview of the Dataset</h2>
#  <p>
#     The initial overview of a dataset is the first step in Exploratory Data Analysis (EDA).
#     It helps to understand the structure, quality, and basic characteristics of the data
#     before performing any cleaning or analysis.
#   </p>
#
#   <h3>1.Understanding the Dataset Structure</h3>
#   <p>At this stage, we examine the dataset to get a basic idea of:</p>
#   <ul>
#     <li>Number of rows (records) and columns (features) using shape</li>
#     <li>Column names and their meaning</li>
#     <li>Data types (numerical, categorical, etc.) using dtypes</li>
#   </ul>
#   <p>
#     This helps in identifying whether the dataset is suitable for analysis and what kind of processing may be required.
#   </p>
#
#   <h3>2.Checking Basic Information</h3>
#   <p>We use functions like <code>.info()</code> and <code>.head()</code> in pandas to:</p>
#   <ul>
#     <li>View the first few records of the dataset</li>
#     <li>Understand column data types</li>
#     <li>Identify non-null values and detect missing data</li>
#   </ul>
#   <p>
#     This step gives a quick snapshot of how complete and structured the dataset is.
#   </p>
#
#   <h3>3.Identifying Data Quality</h3>
#   <p>During the initial overview, we also look for:</p>
#   <ul>
#     <li>Missing values in columns using isnull().sum()</li>
#     <li>Duplicate records using duplicated().sum()</li>
#     <li>Inconsistent or incorrect data types</li>
#     <li>Unexpected values or formatting issues</li>
#   </ul>
#   <p>
#     This helps in planning the data cleaning process effectively.
#   </p>
#
#   <h3>4.Summary Statistics</h3>
#   <p>Basic statistical summary using <code>.describe()</code> provides:</p>
#   <ul>
#     <li>Mean, median, min, max values</li>
#     <li>Distribution of numerical features</li>
#     <li>Initial insight into data spread and variation</li>
#   </ul>
# </div>

# %%
# Number of rows and columns

df.shape
# Out:
# (2610, 20)

# %%
# Data types of each column

df.dtypes
# Out:
# Your Age                                                                       object
# What is your weight                                                           float64
# Your Height                                                                   float64
# What is your gender?                                                           object
# What is your occupation?                                                       object
# What time do you usually go to bed?                                            object
# What time do you usually wake up on working days?                              object
# What time do you usually go to bed on weekends?                                object
# What time do you usually wake up on weekends?                                  object
# How long does it take you to fall asleep after going to bed?                   object
# How many hours of sleep do you get on average per night?                       object
# ...

# %%
# show first few rows of the dataset

df.head()
# Out:
#   Your Age  What is your weight  Your Height What is your gender?  \
# 0    18-30                 83.0          5.1                 Male
# 1    18-30                 68.0          5.8                 Male
# 2    18-30                 50.0          5.8                 Male
# 3    18-30                 70.0          5.5               Female
# 4    18-30                 70.0          5.6                 Male
#
#   What is your occupation? What time do you usually go to bed?  \
# 0                  Student                       10 PM - 12 AM
# 1                  Student                          After 2 AM
# 2                  Student                        12 AM - 2 AM
# 3                  Student                        12 AM - 2 AM
# 4                  Student                        12 AM - 2 AM
#
#   What time do you usually wake up on working days?  \
# 0                                       6 AM - 8 AM
# 1                                      8 AM - 10 AM
# ...

# %%
# show last few rows of the dataset

df.tail()
# Out:
#       Your Age  What is your weight  Your Height What is your gender?  \
# 2605     18-30                 45.0          6.3    Prefer not to say
# 2606     31-50                 78.0          4.6                 Male
# 2607     31-50                 56.0          5.0    Prefer not to say
# 2608  Above 50                 75.0          6.1               Female
# 2609     31-50                 88.0          5.8                 Male
#
#      What is your occupation? What time do you usually go to bed?  \
# 2605                  Student                       10 PM - 12 AM
# 2606     Working Professional                        Before 10 PM
# 2607     Working Professional                        Before 10 PM
# 2608                  Student                       10 PM - 12 AM
# 2609     Working Professional                       10 PM - 12 AM
#
#      What time do you usually wake up on working days?  \
# 2605                                       After 10 AM
# ...

# %%
# Concise summary of the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2610 entries, 0 to 2609
# Data columns (total 20 columns):
#  #   Column                                                                      Non-Null Count  Dtype
# ---  ------                                                                      --------------  -----
#  0   Your Age                                                                    2610 non-null   object
#  1   What is your weight                                                         2610 non-null   float64
#  2   Your Height                                                                 2610 non-null   float64
#  3   What is your gender?                                                        2609 non-null   object
#  4   What is your occupation?                                                    2609 non-null   object
#  5   What time do you usually go to bed?                                         2610 non-null   object
# ...

# %%
# Descriptive statistics for numerical columns in Dataset

df.describe()
# Out:
#        What is your weight  Your Height  \
# count          2610.000000  2610.000000
# mean             69.020284     5.496782
# std              23.320859     0.552014
# min               5.100000     4.000000
# 25%              56.000000     5.100000
# 50%              68.000000     5.500000
# 75%              81.000000     5.900000
# max             934.000000     7.000000
#
#        How would you rate the comfort of your sleeping environment
# count                                        2610.000000
# mean                                            3.140613
# std                                             1.375941
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000

# %%
# Check any null values in dataset

print(df.isnull().sum())
# Out:
# Your Age                                                                       0
# What is your weight                                                            0
# Your Height                                                                    0
# What is your gender?                                                           1
# What is your occupation?                                                       1
# What time do you usually go to bed?                                            0
# What time do you usually wake up on working days?                              0
# What time do you usually go to bed on weekends?                                0
# What time do you usually wake up on weekends?                                  0
# How long does it take you to fall asleep after going to bed?                   1
# How many hours of sleep do you get on average per night?                       0
# What are the main reasons you sleep late?                                      6
# ...

# %%
# Check any duplicate values in dataset

print(df.duplicated().sum())
# Out:
# 10

# %% [markdown]
# <div style="flex: 1; color: white;background-color:#0b1f3a; padding:25px; border-radius:10px;font-family:Arial;">
# <h2>2. Data Pre-Processing</h2>

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">🔹Changing Column Name </h2>
#  <p>
# Column name change refers to the process of modifying dataset column headers to make them more consistent, readable, and easier to use in analysis. This often includes converting column names to lowercase, removing spaces, replacing special characters with underscores, and shortening long or unclear names. For example, a column like "Your Age" renamed to "age". This step improves code readability, avoids errors in Python programming, and ensures uniformity across the dataset for efficient data processing and visualization.
# </p>
# </div>

# %%
df.rename(columns={
    "Your Age": "age",
    "What is your weight": "weight",
    "Your Height": "height",
    "What is your gender?": "gender",
    "What is your occupation?": "occupation",
    "What time do you usually go to bed?": "bedtime",
    "What time do you usually wake up on working days?": "wake_workdays",
    "What time do you usually go to bed on weekends?": "bedtime_weekend",
    "What time do you usually wake up on weekends?": "wake_weekend",
    "How long does it take you to fall asleep after going to bed?": "sleep_latency",
    "How many hours of sleep do you get on average per night?": "sleep_hours",
    "What are the main reasons you sleep late?": "sleep_reasons",
    "Do you have difficulty falling asleep?": "sleep_difficulty",
    "Do you experience breathing difficulties while sleeping": "breathing_difficulty",
    "Do you experience restless legs or involuntary movements during sleep?": "restless_legs",
    "Do you have any medical conditions that might affect your sleep?": "medical_conditions",
    "Do you experience any of the following side effects from late sleeping?": "sleep_sideeffects",
    "How often do you find it hard to concentrate due to lack of sleep?": "concentration_issue",
    "What strategies do you use to cope with the side effects of late sleeping?": "coping_strategies",
    "How would you rate the comfort of your sleeping environment": "sleep_environment_comfort"
}, inplace=True)

# %%
# show dataset with new column name

df
# Out:
#            age  weight  height             gender            occupation  \
# 0        18-30    83.0     5.1               Male               Student
# 1        18-30    68.0     5.8               Male               Student
# 2        18-30    50.0     5.8               Male               Student
# 3        18-30    70.0     5.5             Female               Student
# 4        18-30    70.0     5.6               Male               Student
# ...        ...     ...     ...                ...                   ...
# 2605     18-30    45.0     6.3  Prefer not to say               Student
# 2606     31-50    78.0     4.6               Male  Working Professional
# 2607     31-50    56.0     5.0  Prefer not to say  Working Professional
# 2608  Above 50    75.0     6.1             Female               Student
# 2609     31-50    88.0     5.8               Male  Working Professional
#
#             bedtime wake_workdays bedtime_weekend  wake_weekend  \
# ...

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">🔹Correcting Data Types</h2>

# %%
df.dtypes
# Out:
# age                           object
# weight                       float64
# height                       float64
# gender                        object
# occupation                    object
# bedtime                       object
# wake_workdays                 object
# bedtime_weekend               object
# wake_weekend                  object
# sleep_latency                 object
# sleep_hours                   object
# sleep_reasons                 object
# sleep_difficulty              object
# breathing_difficulty          object
# restless_legs                 object
# medical_conditions            object
# sleep_sideeffects             object
# concentration_issue           object
# coping_strategies             object
# sleep_environment_comfort      int64
# dtype: object

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#  <p>
# it is confirmed that no datatype conversion is required, and the process moves to the next stage of analysis. </p>
# Example:
# <ul>
# <li>Age → object ✔</li>
# <li>Weight → float ✔</li>
# <li>Gender → object (categorical) ✔</li>
# <li>Time columns → object ✔</li>
# <li>sleep_environment_comfort → int ✔</li>
# </ul>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">🔹Handling Data Inconsistency</h2>
# <p>
# The medical_conditions column contains inconsistent categorical values, including medical condition names, variations of "No," and unknown or unclear responses. To ensure uniformity, all text values are standardized by converting them to lowercase and removing leading and trailing whitespace.
#
# A predefined list of non-affected responses (e.g., "no", "na","nothing","none", "never", "না", "না।" etc ) is used to classify entries as "No", indicating absence of any medical condition or side effect. Entries that are missing, unknown, or cannot be clearly interpreted are labeled as "Unknown" to preserve data integrity.
#
# All remaining values, including disease names and descriptive responses, are categorized as "Yes", indicating the presence of a reported medical condition or side effect.
#
# Steps for handling data inconsistency are as follows:</p>
# <ul>
# 1. Convert all text to lowercase</ul>
# <ul>2. Strip leading and trailing whitespace</ul>
# <ul>3. Define a list of "No" and "Unknown" values</ul>
# <ul>4. Classify values into Yes/No</ul>

# %%
#1. Convert all text to lowercase

df["medical_conditions"] = df["medical_conditions"].str.lower()

# %%
# 2. Strip leading and trailing whitespace

df["medical_conditions"] = df["medical_conditions"].str.strip()

# %%
# 3. Define a list of "No" values

no_values = ["no","na","negative","never","no condition","no conditions","no disease","no medical condition","no.","none","nope","not yet by the grace of Allah","nothing","nothing seriuos","n0","না","নাহ"]

# %%
# Define a list of "Unknown" value
unknown_values = ["unknown"]

# %%
# 4. Classify values into Yes/No/Unknown
def categorize(x):
    if x in no_values:
        return "No"
    elif x in unknown_values:
        return "Unknown"
    else:
        return "Yes"
df["medical_conditions"] = df["medical_conditions"].apply(categorize)

# %%
df["medical_conditions"].value_counts()
# Out:
# medical_conditions
# Yes        1823
# No          453
# Unknown     334
# Name: count, dtype: int64

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">🔹Handling Missing Values</h2>

# %%
print(df.isnull().sum())
# Out:
# age                           0
# weight                        0
# height                        0
# gender                        1
# occupation                    1
# bedtime                       0
# wake_workdays                 0
# bedtime_weekend               0
# wake_weekend                  0
# sleep_latency                 1
# sleep_hours                   0
# sleep_reasons                 6
# sleep_difficulty              0
# breathing_difficulty          0
# restless_legs                 0
# medical_conditions            0
# sleep_sideeffects            14
# concentration_issue           0
# coping_strategies            15
# sleep_environment_comfort     0
# dtype: int64

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
# <p>
# Missing values in the dataset are handled by applying appropriate replacement strategies based on the nature of each feature. Since the affected columns are mostly categorical or text-based, meaningful default categories are assigned to preserve data consistency and avoid bias.</p>
# <ul>
# <li>Gender: Missing values are replaced with "Prefer not to say" to respect non-disclosure and maintain an existing valid category structure.
# <li>Occupation: Missing entries are filled with "Unknown" to indicate unavailable information without assuming a specific job type.
# <li>sleep_latency: Missing values are replaced with "Unknown" since the response is categorical (time ranges) and cannot be accurately inferred.
# <li>sleep_reasons: Missing values are filled with "Not specified" to clearly indicate that no reason was provided.
# <li>sleep_sideeffects: Missing values are replaced with "No side effects reported" to distinguish between absence of response and absence of symptoms.
# <li>coping_strategies: Missing values are filled with "No coping strategy reported" to reflect non-response while maintaining interpretability.
# </li>
# </ul>
# </div>

# %%
# Gender (male, female, prefer not to say)

df["gender"] = df["gender"].fillna("Prefer not to say")

# %%
# Occupation

df["occupation"] = df["occupation"].fillna("Unknown")

# %%
# Sleep latency (categorical ranges)

df["sleep_latency"] = df["sleep_latency"].fillna("Unknown")

# %%
# Sleep reasons

df["sleep_reasons"] = df["sleep_reasons"].fillna("Not specified")

# %%
# Sleep side effects

df["sleep_sideeffects"] = df["sleep_sideeffects"].fillna("No side effects reported")

# %%
# Coping strategies

df["coping_strategies"] = df["coping_strategies"].fillna("No coping strategy reported")

# %%
# Check if there are any null values

print(df.isnull().sum())
# Out:
# age                          0
# weight                       0
# height                       0
# gender                       0
# occupation                   0
# bedtime                      0
# wake_workdays                0
# bedtime_weekend              0
# wake_weekend                 0
# sleep_latency                0
# sleep_hours                  0
# sleep_reasons                0
# sleep_difficulty             0
# breathing_difficulty         0
# restless_legs                0
# medical_conditions           0
# sleep_sideeffects            0
# concentration_issue          0
# coping_strategies            0
# sleep_environment_comfort    0
# dtype: int64

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">🔹Removing duplicates</h2>

# %%
# Checks how many duplicate rows

print(df.duplicated().sum())
# Out:
# 11

# %%
# Show duplicate rows

df[df.duplicated()]
# Out:
#         age  weight  height  gender            occupation        bedtime  \
# 392   31-50    76.0     5.8    Male           Freelancing   12 AM - 2 AM
# 470   31-50    52.0     5.4    Male           Freelancing  10 PM - 12 AM
# 866   18-30    49.0     4.2  Female             Housewife  10 PM - 12 AM
# 950   31-50    72.0     5.6  Female  Working Professional  10 PM - 12 AM
# 1302  18-30    92.0     5.5    Male               Student   12 AM - 2 AM
# 1308  18-30    92.0     5.5    Male               Student   12 AM - 2 AM
# 1309  18-30    92.0     5.5    Male               Student   12 AM - 2 AM
# 1311  18-30    92.0     5.5    Male               Student   12 AM - 2 AM
# 1312  18-30    92.0     5.5    Male               Student   12 AM - 2 AM
# 1340  18-30    92.0     5.5    Male               Student   12 AM - 2 AM
# 1343  18-30    92.0     5.5    Male               Student   12 AM - 2 AM
#
#      wake_workdays bedtime_weekend  wake_weekend  sleep_latency  \
# ...

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
# <p>
# The dataset contains 11 duplicate records, meaning some rows are repeated more than once with identical or highly similar values across all features.
# Duplicate records in the dataset are removed using the pandas function drop_duplicates(), which helps ensure data quality and prevents repeated entries from affecting analysis results.
# </p>
# </div>

# %%
# Remove duplicate rows

df = df.drop_duplicates()

# %%
# Check for duplicates

print(df.duplicated().sum())
# Out:
# 0

# %%
df.shape
# Out:
# (2599, 20)

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
# <p>
# After removing duplicate records, the dataset consists of 2599 rows and 20 columns
# </p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">🔹Creating Derived Columns</h2>
# <p>
# Several new features were derived from the original dataset, including BMI, BMI category and sleep latency category. These features were created to transform raw data into meaningful groups, enabling better analysis of relationships between health indicators and sleep behavior.
# </p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;font size=10">1.BMI Column</h2>
# <p>
# Body Mass Index (BMI) was calculated to assess the relationship between an individual's weight and height. Since the given height was in feet (5.1 ft), it was first converted into meters using the standard conversion factor (1 foot = 0.3048 meters). The converted height (1.554 meters) was then squared as required by the BMI formula.
# <ul>
#     <b><I>BMI = Weight/Height</I></b></ul></div>
# </p>

# %%
df["bmi"] = round(df["weight"] / (df["height"]*0.3048)**2,2)

# %%
print(df["bmi"])
# Out:
# 0       34.35
# 1       21.76
# 2       16.00
# 3       24.91
# 4       24.03
#         ...
# 2605    12.20
# 2606    39.68
# 2607    24.11
# 2608    21.70
# 2609    28.16
# Name: bmi, Length: 2599, dtype: float64

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;font size=10">2.BMI Category Column</h2>
# <p>
# The BMI Category column is a derived categorical feature created from the calculated Body Mass Index (BMI) values. It is used to group individuals into standard weight status categories based on their BMI score, making the data easier to interpret and analyze.
# The categories are typically defined as:</p>
# <ul>
# <li>Underweight: BMI < 18.5</li>
# <li>Normal weight: 18.5 ≤ BMI < 24.9</li>
# <li>Overweight: 25 ≤ BMI < 29.9</li>
# <li>Obese: BMI ≥ 30</li>
# </ul>
# <p>
# This transformation converts a continuous numerical variable (BMI) into a categorical variable, which is useful for exploratory data analysis (EDA), visualization, and identifying health risk patterns across different population groups. It helps in comparing distributions and understanding how many individuals fall into each weight category.
# </p>

# %%
df["bmi_category"] = df["bmi"].apply(
    lambda x: "Underweight" if x < 18.5
    else "Normal" if x < 25
    else "Overweight" if x < 30
    else "Obese"
)

# %%
print(df["bmi_category"])
# Out:
# 0             Obese
# 1            Normal
# 2       Underweight
# 3            Normal
# 4            Normal
#            ...
# 2605    Underweight
# 2606          Obese
# 2607         Normal
# 2608         Normal
# 2609     Overweight
# Name: bmi_category, Length: 2599, dtype: object

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;font size=10">3.Sleep Latency Level</h2>
# <p>
# The Sleep Latency Category column represents the time taken by an individual to fall asleep after going to bed, converted into meaningful categorical groups for easier analysis and interpretation. Sleep latency is an important indicator of sleep quality and potential sleep-related issues.
#
# The raw values (e.g., "less than 15 min", "15–30 min", "31–60 min", "more than 60 min") are grouped into standardized categories such as:</p>
# <ul>
# <li>Fast: Falls asleep quickly (less than 15 minutes)</li>
# <li>Normal: Moderate time to fall asleep (15–30 minutes)</li>
# <li>Slow: Takes longer than usual (31–60 minutes)</li>
# <li>Very Slow: Significant difficulty falling asleep (more than 60 minutes)</li>
# </ul>
# <p>Before deriving the sleep latency level, the column is verified for any "Unknown" values, as these were handled during the missing value imputation step.</p>

# %%
df[df["sleep_latency"]=="unknown"]
# Out:
# Empty DataFrame
# Columns: [age, weight, height, gender, occupation, bedtime, wake_workdays, bedtime_weekend, wake_weekend, sleep_latency, sleep_hours, sleep_reasons, sleep_difficulty, breathing_difficulty, restless_legs, medical_conditions, sleep_sideeffects, concentration_issue, coping_strategies, sleep_environment_comfort, bmi, bmi_category]
# Index: []
#
# [0 rows x 22 columns]

# %%
df["latency_level"] = df["sleep_latency"].apply(
    lambda x: "Fast" if x == "Less than 15 minutes"
    else "Normal" if x == "15-30 minutes"
    else "Slow" if x == "31-60 minutes"
    else "Very Slow" 
)

# %%
df["latency_level"]
# Out:
# 0          Normal
# 1          Normal
# 2          Normal
# 3       Very Slow
# 4            Fast
#           ...
# 2605       Normal
# 2606         Slow
# 2607    Very Slow
# 2608    Very Slow
# 2609         Slow
# Name: latency_level, Length: 2599, dtype: object

# %%
# Show dataset
df
# Out:
#            age  weight  height             gender            occupation  \
# 0        18-30    83.0     5.1               Male               Student
# 1        18-30    68.0     5.8               Male               Student
# 2        18-30    50.0     5.8               Male               Student
# 3        18-30    70.0     5.5             Female               Student
# 4        18-30    70.0     5.6               Male               Student
# ...        ...     ...     ...                ...                   ...
# 2605     18-30    45.0     6.3  Prefer not to say               Student
# 2606     31-50    78.0     4.6               Male  Working Professional
# 2607     31-50    56.0     5.0  Prefer not to say  Working Professional
# 2608  Above 50    75.0     6.1             Female               Student
# 2609     31-50    88.0     5.8               Male  Working Professional
#
#             bedtime wake_workdays bedtime_weekend  wake_weekend  \
# ...

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">🔹Handling Outliers</h2>
# <p>
# Outliers in the BMI column are identified using a percentile-based approach by computing lower and upper thresholds using extreme quantiles. Values outside these bounds are considered outliers and are removed to reduce their impact. This helps improve data quality and ensures more reliable analysis results.</p>

# %%
df.describe()
# Out:
#             weight       height  sleep_environment_comfort          bmi
# count  2599.000000  2599.000000                2599.000000  2599.000000
# mean     68.968811     5.497153                   3.136206    25.259965
# std      23.333491     0.552557                   1.376950    10.894401
# min       5.100000     4.000000                   1.000000     1.730000
# 25%      56.000000     5.100000                   2.000000    19.900000
# 50%      68.000000     5.500000                   3.000000    24.030000
# 75%      81.000000     5.900000                   4.000000    29.060000
# max     934.000000     7.000000                   5.000000   418.720000

# %%
# Detect outliers using percentile

min_bmi, max_bmi = df.bmi.quantile([0.001, 0.999])
min_bmi, max_bmi
# Out:
# (6.281619999999998, 56.02044000000061)

# %%
df[df["bmi"]<min_bmi]
# Out:
#        age  weight  height  gender   occupation        bedtime wake_workdays  \
# 566  31-50     5.8     6.0    Male  Freelancing     After 2 AM   After 10 AM
# 609  31-50     5.1     4.7  Female  Freelancing     After 2 AM  8 AM - 10 AM
# 923  18-30     6.0     5.0  Female  Freelancing  10 PM - 12 AM   6 AM - 8 AM
#
#     bedtime_weekend  wake_weekend         sleep_latency  ...  \
# 566      After 2 AM   After 10 AM         15-30 minutes  ...
# 609    12 AM - 2 AM   After 10 AM  More than 60 minutes  ...
# 923   10 PM - 12 AM  8 AM - 10 AM         15-30 minutes  ...
#
#     breathing_difficulty restless_legs medical_conditions  \
# 566               Rarely        Rarely                Yes
# 609               Always         Often                Yes
# 923               Always         Often                Yes
#
#           sleep_sideeffects concentration_issue  \
# 566         Health issues                 Often
# 609          Fatigue;Others           Sometimes
# ...

# %%
df[df["bmi"]>max_bmi]
# Out:
#            age  weight  height  gender   occupation        bedtime  \
# 1175     31-50    93.0     4.2    Male      Student   12 AM - 2 AM
# 1176  Under 18    98.0     4.2    Male       Others   12 AM - 2 AM
# 1179     31-50   934.0     4.9  Female  Freelancing  10 PM - 12 AM
#
#      wake_workdays bedtime_weekend  wake_weekend  sleep_latency  ...  \
# 1175  8 AM - 10 AM   10 PM - 12 AM  8 AM - 10 AM  31-60 minutes  ...
# 1176  8 AM - 10 AM    Before 10 PM  8 AM - 10 AM  15-30 minutes  ...
# 1179  8 AM - 10 AM    12 AM - 2 AM  8 AM - 10 AM  15-30 minutes  ...
#
#      breathing_difficulty restless_legs medical_conditions  \
# 1175               Always         Often                Yes
# 1176               Always        Rarely                Yes
# 1179               Always         Often                Yes
#
#                                       sleep_sideeffects concentration_issue  \
# 1175           Fatigue;Health issues  ;Back Pain;Others              Always
# ...

# %%
# remove outlier

df_new = df[(df["bmi"] >= min_bmi) & (df["bmi"] <= max_bmi)]

# %%
df_new
# Out:
#            age  weight  height             gender            occupation  \
# 0        18-30    83.0     5.1               Male               Student
# 1        18-30    68.0     5.8               Male               Student
# 2        18-30    50.0     5.8               Male               Student
# 3        18-30    70.0     5.5             Female               Student
# 4        18-30    70.0     5.6               Male               Student
# ...        ...     ...     ...                ...                   ...
# 2605     18-30    45.0     6.3  Prefer not to say               Student
# 2606     31-50    78.0     4.6               Male  Working Professional
# 2607     31-50    56.0     5.0  Prefer not to say  Working Professional
# 2608  Above 50    75.0     6.1             Female               Student
# 2609     31-50    88.0     5.8               Male  Working Professional
#
#             bedtime wake_workdays bedtime_weekend  wake_weekend  \
# ...

# %%
# statistical summary after removing outliers

df_new.describe()
# Out:
#             weight       height  sleep_environment_comfort          bmi
# count  2593.000000  2593.000000                2593.000000  2593.000000
# mean     68.688022     5.498689                   3.133822    25.109364
# std      15.866771     0.551498                   1.375850     7.599916
# min      18.000000     4.000000                   1.000000     8.770000
# 25%      56.000000     5.100000                   2.000000    19.900000
# 50%      68.000000     5.500000                   3.000000    24.030000
# 75%      81.000000     5.900000                   4.000000    29.000000
# max     180.000000     7.000000                   5.000000    55.530000

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">🔹Feature Transformation</h2>
# <p>
# Bedtime, wake-up time, sleep latency, and sleep duration variables were transformed from categorical time-based responses into numerical values using predefined mapping techniques. Since these variables were originally recorded in ranges (e.g., "10 PM – 12 AM", "6–8 hours") and categorical time intervals (e.g., "Less than 15 minutes", "After 2 AM"), each category was assigned a representative numeric value based on its midpoint or logical approximation. This transformation ensured that all time-related and duration-based features were represented in a consistent numeric format</p>
# <p>
# The columns sleep_reasons, sleep_sideeffects, and coping_strategies contain multiple responses in a single cell, separated by a delimiter(;). To analyze these multi-choice responses effectively, feature transformation using explode() is applied.
# </p>

# %%
# Mapping bedtime

bedtime_mapping = {
    "Before 10 PM": 21,      # 9 PM (approx)
    "10 PM - 12 AM": 23,     # average of 22–24 → 23
    "12 AM - 2 AM": 25,       # average of 24–26 → 25
    "After 2 AM": 27          # representative value
}

df_new["bedtime_hour"] = df_new["bedtime"].map(bedtime_mapping)

# %%
df_new["bedtime_hour"]
# Out:
# 0       23
# 1       27
# 2       25
# 3       25
# 4       25
#         ..
# 2605    23
# 2606    21
# 2607    21
# 2608    23
# 2609    23
# Name: bedtime_hour, Length: 2593, dtype: int64

# %%
# Mapping wake_workdays

wake_mapping  = {
    "Before 6 AM": 5,       # 5 AM (approx)
    "6 AM - 8 AM": 7,       # average of 6–8 → 7
    "8 AM - 10 AM": 9,      # average of 8–10 → 9
    "After 10 AM": 11       # representative value
}

df_new["wake_workdays_hour"] = df_new["wake_workdays"].map(wake_mapping)

# %%
df_new["wake_workdays_hour"]
# Out:
# 0        7
# 1        9
# 2        9
# 3        7
# 4        7
#         ..
# 2605    11
# 2606     9
# 2607     9
# 2608     7
# 2609     5
# Name: wake_workdays_hour, Length: 2593, dtype: int64

# %%
# Mapping bedtime_weekend

bedtime_weekend_mapping = {
    "Before 10 PM": 21,      # 9 PM (approx)
    "10 PM - 12 AM": 23,     # average of 22–24 → 23
    "12 AM - 2 AM": 25,       # average of 24-26 → 25
    "After 2 AM": 27          # representative value
}

df_new["bedtime_weekend_hour"] = df_new["bedtime_weekend"].map(bedtime_weekend_mapping)

# %%
df_new["bedtime_weekend_hour"]
# Out:
# 0       25
# 1       27
# 2       25
# 3       27
# 4       25
#         ..
# 2605    27
# 2606    23
# 2607    21
# 2608    21
# 2609    23
# Name: bedtime_weekend_hour, Length: 2593, dtype: int64

# %%
# Mapping wake_weekend

wake_weekend_mapping  = {
    "Before 6 AM": 5,
    "6 AM - 8 AM": 7,
    "8 AM - 10 AM": 9,
    "After 10 AM": 11
}

df_new["wake_weekend_hour"] = df_new["wake_weekend"].map(wake_weekend_mapping)

# %%
df_new["wake_weekend_hour"]
# Out:
# 0        9
# 1       11
# 2        9
# 3       11
# 4        9
#         ..
# 2605     9
# 2606    11
# 2607    11
# 2608     5
# 2609     5
# Name: wake_weekend_hour, Length: 2593, dtype: int64

# %%
# Mapping sleep_latency

sleep_latency_mapping={
    "Less than 15 minutes": 7.5,
    "15-30 minutes": 22.5,
    "31-60 minutes": 45,
    "More than 60 minutes": 75
}

df_new["sleep_latency_numeric"] = df_new["sleep_latency"].map(sleep_latency_mapping)

# %%
df_new["sleep_latency_numeric"]
# Out:
# 0       22.5
# 1       22.5
# 2       22.5
# 3       75.0
# 4        7.5
#         ...
# 2605    22.5
# 2606    45.0
# 2607    75.0
# 2608    75.0
# 2609    45.0
# Name: sleep_latency_numeric, Length: 2593, dtype: float64

# %%
sleep_hours_mapping = {
    "Less than 4 hours": 3.5,
    "4-6 hours": 5,
    "6-8 hours": 7,
    "More than 8 hours": 8.5
}

df_new["sleep_hours_numeric"] = df_new["sleep_hours"].map(sleep_hours_mapping)

# %%
df_new["sleep_hours_numeric"]
# Out:
# 0       7.0
# 1       5.0
# 2       7.0
# 3       5.0
# 4       7.0
#        ...
# 2605    3.5
# 2606    3.5
# 2607    5.0
# 2608    3.5
# 2609    5.0
# Name: sleep_hours_numeric, Length: 2593, dtype: float64

# %% [markdown]
# #### Exploding sleep_reasons Column

# %%
# 1.Split the values
# values are seperated by;

df_new["sleep_reasons"] = df_new["sleep_reasons"].str.split(";")

# %%
# 2.Explode into separate rows

df_reason = df_new.explode("sleep_reasons")

# Now each reason becomes a separate row.

# %%
# 3.Remove extra spaces

df_reason["sleep_reasons"] = df_reason["sleep_reasons"].str.strip()

# %%
df_reason["sleep_reasons"]
# Out:
# 0                    Study & Exam Purpose
# 0                   Social Media/Internet
# 0       Entertainment (TV, movies, games)
# 0        Insomnia or other sleep disorder
# 0                       Stress or anxiety
#                       ...
# 2608                    professional Work
# 2608     Insomnia or other sleep disorder
# 2609                Social Media/Internet
# 2609                    Stress or anxiety
# 2609                               Others
# Name: sleep_reasons, Length: 6644, dtype: object

# %% [markdown]
# #### Exploding sleep_sideeffects Column

# %%
# 1.Split the values
# values are seperated by;

df_new["sleep_sideeffects"] = df_new["sleep_sideeffects"].str.split(";")

# %%
# 2.Explode into separate rows

df_sideeffects = df_new.explode("sleep_sideeffects")

# Now each reason becomes a separate row.

# %%
# 3.Remove extra spaces

df_sideeffects["sleep_sideeffects"] = df_sideeffects["sleep_sideeffects"].str.strip()

# %%
df_sideeffects["sleep_sideeffects"]
# Out:
# 0                                      Fatigue
# 0       Decreased academic or work performance
# 0                                Health issues
# 1                     Difficulty concentrating
# 1                  Mood swings or irritability
#                          ...
# 2608                                 Back Pain
# 2608    Decreased academic or work performance
# 2609                                   Fatigue
# 2609                  Difficulty concentrating
# 2609                             Health issues
# Name: sleep_sideeffects, Length: 6671, dtype: object

# %% [markdown]
# #### Exploding coping_strategies Column

# %%
# 1.Split the values
# values are seperated by;

df_new["coping_strategies"] = df_new["coping_strategies"].str.split(";")

# %%
# 2.Explode into separate rows

df_coping = df_new.explode("coping_strategies")

# Now each reason becomes a separate row.

# %%
# 3.Remove extra spaces

df_coping["coping_strategies"] = df_coping["coping_strategies"].str.strip()

# %%
df_coping["coping_strategies"]
# Out:
# 0       Caffeine or other stimulants
# 0                           Exercise
# 0                             Others
# 1                Naps during the day
# 1       Caffeine or other stimulants
#                     ...
# 2607    Caffeine or other stimulants
# 2608           Relaxation techniques
# 2608    Caffeine or other stimulants
# 2609             Naps during the day
# 2609    Caffeine or other stimulants
# Name: coping_strategies, Length: 4788, dtype: object

# %% [markdown]
# <div style="flex: 1; color: white;background-color:#0b1f3a; padding:25px; border-radius:10px;font-family:Arial;">
# <h2>3. Exploratory Data Analysis (EDA)</h2>

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">🔹Univariate Analysis</h2>

# %% [markdown]
# ### 1. What is the distribution of age?

# %%
df_new["age"].value_counts()
# Out:
# age
# 18-30       942
# 31-50       709
# Above 50    481
# Under 18    461
# Name: count, dtype: int64

# %%
# Percentage Distribution of age

(df_new["age"].value_counts() / 2599 )* 100
# Out:
# age
# 18-30       36.244710
# 31-50       27.279723
# Above 50    18.507118
# Under 18    17.737591
# Name: count, dtype: float64

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📊 Statistical Summaries</h2>
# <ul>
# <li>The dataset is dominated by the 18–30 age group (36.24%), indicating a strong presence of young adults.</li>
# <li>The working-age population (18–50) forms the majority, contributing about 63.52% of the dataset.</li>
# <li>Older adults (Above 50) represent a smaller portion (18.51%), suggesting limited representation of elderly individuals.</li>
# <li>Under 18 group (17.73%) is similar in size to the older population, indicating balanced representation at the extremes</li>
# </ul>

# %% [markdown]
# ### 2. What is the distribution of occupation?

# %%
df_new["occupation"].value_counts()
# Out:
# occupation
# Student                 829
# Working Professional    533
# Freelancing             390
# Others                  326
# Unemployment            294
# Housewife               220
# Unknown                   1
# Name: count, dtype: int64

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📊 Statistical Summaries</h2>
# <ul>
# <li>Students (829) form the largest group, indicating that the dataset is predominantly composed of student respondents.</li>
# <li>Working professionals (533) represent the second-largest category, showing a significant portion of employed individuals.</li>
# <li>Freelancing (390) also accounts for a notable share, reflecting participation from independent workers.</li>
# <li>Others (326) suggests the presence of additional unspecified occupational categories.</li>
# <li>Unemployment (294) indicates a moderate proportion of respondents without active employment.</li>
# <li>Housewives (220) form a smaller but relevant group within the dataset.</li>
# <li>Unknown (1) is negligible, indicating minimal missing or undefined data in this variable.</li>
# </ul>

# %% [markdown]
# ### 3.What are the most common reasons for poor sleep among individuals, and how are they distributed?

# %%
df_reason["sleep_reasons"].value_counts()
# Out:
# sleep_reasons
# Social Media/Internet                1152
# Entertainment (TV, movies, games)    1032
# Stress or anxiety                     981
# Study & Exam Purpose                  948
# professional Work                     846
# Others                                845
# Insomnia or other sleep disorder      834
# Not specified                           6
# Name: count, dtype: int64

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📊 Statistical Summaries</h2>
# <ul>
# <li>The most common sleep disruption factor is Social Media/Internet usage, indicating strong digital influence on sleep patterns.</li>
# <li>Entertainment activities  and Stress or anxiety are also major contributors.</li>
# <li>Academic and work-related factors combined show that lifestyle pressure significantly affects sleep.</li>
# <li>Insomnia or sleep disorders indicate a notable health-related sleep issue segment.</li>
# <li>The Not specified category is negligible and does not impact analysis.</li>
# </ul>

# %% [markdown]
# ### 4. Which sleep side effects are most commonly reported, and how are they distributed?

# %%
df_sideeffects["sleep_sideeffects"].value_counts()
# Out:
# sleep_sideeffects
# Fatigue                                   1119
# Health issues                             1023
# Mood swings or irritability               1007
# Difficulty concentrating                   952
# Decreased academic or work performance     881
# Others                                     875
# Back Pain                                  800
# No side effects reported                    14
# Name: count, dtype: int64

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📊 Statistical Summaries</h2>
# <ul>
# <li>Fatigue (1119) is the most commonly reported side effect, indicating widespread tiredness among respondents.</li>
# <li>Health issues (1023) and mood swings or irritability (1007) are also highly prevalent, reflecting significant physical and emotional impacts.</li>
# <li>Difficulty concentrating (952) suggests noticeable cognitive impairment due to sleep problems.</li>
# <li>Decreased academic or work performance (881) highlights reduced productivity levels.</li>
# <li>A substantial number of responses fall under "Others" (875), indicating additional unspecified side effects.</li>
# <li>Back pain (800) is another commonly reported physical issue.</li>
# <li>Only 14 respondents reported no side effects, showing that sleep-related problems affect nearly all individuals.</li>
# </ul>

# %% [markdown]
# ### 5. Which coping strategies are most commonly adopted by individuals, and what does their distribution reveal about behavioral patterns in managing sleep problems?"

# %%
df_coping["coping_strategies"].value_counts()
# Out:
# coping_strategies
# Naps during the day             1055
# Caffeine or other stimulants    1020
# Exercise                         929
# Others                           887
# Relaxation techniques            882
# No coping strategy reported       15
# Name: count, dtype: int64

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📊 Statistical Summaries</h2>
# <ul>
# <li>Naps during the day (1055) is the most commonly used coping strategy, indicating a preference for compensating sleep loss.</li>
# <li>Caffeine or other stimulants (1020) are also widely used, suggesting reliance on external energy boosters.</li>
# <li>Exercise (929) is a moderately common strategy, reflecting some adoption of healthy coping mechanisms.</li>
# <li>A notable number of responses fall under "Others" (887), indicating additional unspecified strategies.</li>
# <li>Relaxation techniques (882) are used by a considerable portion of respondents, showing awareness of stress management methods.</li>
# <li>Only 15 respondents reported no coping strategy, suggesting that the majority actively try to manage sleep-related issues.</li>
# </ul>

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">🔹Bivariate Analysis</h2>

# %% [markdown]
# ### 6. What is the percentage distribution of sleep latency levels across different age groups?

# %%
pd.crosstab(df_new["age"], df_new["latency_level"], normalize="index") * 100
# Out:
# latency_level       Fast     Normal       Slow  Very Slow
# age
# 18-30          23.248408  32.484076  24.946921  19.320594
# 31-50          21.579690  28.772920  28.067701  21.579690
# Above 50       22.245322  28.274428  22.661123  26.819127
# Under 18       23.210412  25.596529  30.151844  21.041215

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📊 Statistical Summaries</h2>
# <ul>
# <li>The 31–50 age group shows a higher proportion of Slow and Very Slow sleep latency, indicating more difficulty falling asleep in this group.</li>
# <li>The Above 50 age group also has a noticeable increase in Very Slow latency, suggesting reduced sleep efficiency with age.</li>
# <li>The Under 18 group shows a relatively balanced distribution but slightly higher Slow latency, indicating occasional sleep delays.</li>
# <li>The 18–30 age group has comparatively higher proportions of Fast and Normal latency, indicating better sleep onset patterns.</li>
# <li>Overall, sleep latency tends to increase with age, especially in middle-aged and older groups.</li>
# </ul>

# %% [markdown]
# ### 7. How does BMI category vary with sleep time?

# %%
pd.crosstab(df_new["sleep_hours"], df_new["bmi_category"])
# Out:
# bmi_category       Normal  Obese  Overweight  Underweight
# sleep_hours
# 4-6 hours             319    160         181          116
# 6-8 hours             344    188         196          162
# Less than 4 hours     155    109         102           84
# More than 8 hours     167    104          95          111

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📊 Statistical Summaries</h2>
# <ul>
# <li>The 6–8 hours sleep group shows the most stable and healthy distribution pattern.<\li>
# <li>Extremely low sleep (<4 hours) shows a slightly poorer BMI profile.<\li>
# <li>Very long sleep (>8 hours) does not show clear health advantage.<\li>
# <li>Overall, BMI distribution does not change drastically but sleep extremes show weaker patterns.<\li>
# </ul>

# %% [markdown]
# ### 8. Does occupation influence the type of sleep side effects?

# %%
pd.crosstab(df_sideeffects["occupation"], df_sideeffects["sleep_sideeffects"])
# Out:
# sleep_sideeffects     Back Pain  Decreased academic or work performance  \
# occupation
# Freelancing                 126                                     102
# Housewife                    69                                      73
# Others                      117                                     106
# Student                     232                                     299
# Unemployment                 92                                      97
# Unknown                       1                                       1
# Working Professional        163                                     203
#
# sleep_sideeffects     Difficulty concentrating  Fatigue  Health issues  \
# occupation
# Freelancing                                145      161            159
# Housewife                                   74       94             84
# Others                                     120      134            153
# Student                                    308      369            298
# ...

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📊 Statistical Summaries</h2>
# <ul>
# <li>Occupation does influence sleep side effects patterns.</li>
# <li>Students and working professionals are the most affected groups.</li>
# <li>Fatigue, concentration issues, and mood swings are the most common problems across all occupations.</li>
# </ul>

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">🔹Multivariate Analysis</h2>

# %% [markdown]
# ### 9. Do individuals with medical conditions and breathing difficulties report higher concentration issues?

# %%
pd.crosstab([df_new["medical_conditions"],df_new["breathing_difficulty"]],df_new["concentration_issue"])
# Out:
# concentration_issue                      Always  Never  Often  Rarely  \
# medical_conditions breathing_difficulty
# No                 Always                    10      7     15       6
#                    Never                     16     41     33      40
#                    Often                     16     10     12       7
#                    Rarely                     8      7     14      11
#                    Sometimes                 11      7     16      10
# Unknown            Always                     6      6      8       9
#                    Never                      8     19     10      18
#                    Often                     11     11     15      12
#                    Rarely                     8     10     14      13
#                    Sometimes                 19     14     22      21
# Yes                Always                    89     59     93      69
#                    Never                     74     65     84      64
# ...

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📊 Statistical Summaries</h2>
# <ul>
# <li>Individuals with medical conditions experience more frequent concentration issues</li>
# <li>Individuals without medical conditions report fewer or less severe concentration problems</li>
# <li>Medical condition status is the dominant factor affecting concentration problems</li>

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">🔹Group by</h2>

# %% [markdown]
# ### 10. Which age group has the highest average sleep duration?

# %%
df_new.groupby("age")["sleep_hours_numeric"].mean().round(2)
# Out:
# age
# 18-30       5.97
# 31-50       6.06
# Above 50    6.06
# Under 18    6.29
# Name: sleep_hours_numeric, dtype: float64

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📊 Statistical Summaries</h2>
# <ul>
# <li>Under 18 age group has the highest average sleep hours (6.29 hrs), meaning younger individuals tend to sleep more compared to other groups.</li>
# <li>18–30 age group has the lowest average sleep hours (5.97 hrs), suggesting reduced sleep possibly due to study, work pressure, or lifestyle habits.</li>
# <li>31–50 and Above 50 groups show similar sleep patterns 6.06 hrs, indicating stable sleep behavior in adulthood and older age.</li>

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">🔹Pivot Table</h2>

# %% [markdown]
# ### 11.Do people with medical conditions experience more sleep side effects and sleep difficulty?

# %%
pd.pivot_table(df_new,
               index="medical_conditions",
               columns="sleep_difficulty",
               values="sleep_sideeffects",
               aggfunc="count")
# Out:
# sleep_difficulty    Always  Never  Often  Rarely  Sometimes
# medical_conditions
# No                      58    132     58     107         98
# Unknown                 60     59     69      57         89
# Yes                    390    301    413     329        373

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📊 Statistical Summaries</h2>
# <ul>
# <li>People with medical conditions (Yes) show the highest sleep difficulty across all categories.</li>
# <li>The "Often" (417) and "Always" (391) groups are especially high for those with medical conditions.</li>
# <li>People with no medical conditions mostly report “Never” (132), indicating better sleep quality.</li>
# <li>Overall, medical conditions are strongly associated with increased sleep difficulty.</li>
# </ul>

# %% [markdown]
# ### 12. How do workdays bedtime and wake time differ across conditions?

# %%
pd.pivot_table(df_new,
               values="sleep_hours_numeric",
               index="bedtime",
               columns="wake_workdays",
               aggfunc="mean")
# Out:
# wake_workdays  6 AM - 8 AM  8 AM - 10 AM  After 10 AM  Before 6 AM
# bedtime
# 10 PM - 12 AM     6.077160      6.152047     6.111650     6.023179
# 12 AM - 2 AM      6.240741      6.084135     6.169643     6.169118
# After 2 AM        5.944751      6.154362     6.329630     5.678571
# Before 10 PM      5.805556      6.095833     5.516484     6.248031

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📊 Statistical Summaries</h2>
# <ul>
# <li>Highest sleep (6.32 hrs) occurs in late sleepers who also wake late.</li>
# <li>12 AM–2 AM bedtime shows stable sleep across wake times.</li>
# <li>Mismatched schedules (early sleep + late wake or late sleep + early wake) reduce sleep hours</li>
# <li>Overall, consistent sleep routine leads to better sleep duration.</li>
# </ul>

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">🔹Correlation analysis</h2>

# %% [markdown]
# ### 13. What is the relationship between sleep hours and sleep environment comfort?

# %%
df_new[["sleep_hours_numeric", "sleep_environment_comfort"]].corr()
# Out:
#                            sleep_hours_numeric  sleep_environment_comfort
# sleep_hours_numeric                   1.000000                   0.010623
# sleep_environment_comfort             0.010623                   1.000000

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📊 Statistical Summaries</h2>
# <p>Sleep hours show almost no correlation (0.01) with sleep environment comfort, indicating that environmental comfort alone does not significantly influence sleep duration in this dataset</p>

# %% [markdown]
# <div style="flex: 1; color: white;background-color:#0b1f3a; padding:25px; border-radius:10px;font-family:Arial;">
# <h2>4. Visualization</h2>

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">🔹1. Univariate</h2>

# %% [markdown]
# ### 1. What are the most common reasons for sleeping late?

# %%
data = df_reason["sleep_reasons"].value_counts().reset_index()
data.columns = ["sleep_reasons", "count"]

# %%
plt.figure(figsize=(8,6))

sns.barplot(
    data=data,
    x="sleep_reasons",
    y="count",
    palette="viridis"
)

plt.title("Reasons for Sleeping Late")
plt.xlabel("Reason")
plt.ylabel("Count")

plt.xticks(rotation=30, ha='right')
plt.tight_layout()

plt.show()

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📊 Insight</h2
# <p>The most common reasons for sleeping late are primarily related to screen exposure, followed by psychological factors such as stress or anxiety, which play a key role in delayed sleep patterns. Work and study pressure also contribute, indicating that both lifestyle habits and academic or occupational demands lead to irregular sleep timing.</p>

# %% [markdown]
# ### 2. What side effects are most commonly experienced?

# %%
df_sideeffects["sleep_sideeffects"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%",
    figsize=(7,7),
    startangle=90,
    colors = ["#5DADE2", "#58D68D", "#F5B041", "#EC7063", "#AF7AC5","purple","indigo","deeppink"]
)
plt.title("Side Effects of Late Sleeping")
plt.ylabel("")
plt.legend(title="Side Effect", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📊 Insight</h2
# <p>The most commonly experienced side effects are fatigue and health-related issues, followed by mood swings, difficulty concentrating, and reduced academic or work performance. This indicates that poor sleep has both physical and psychological consequences, significantly affecting energy levels, emotional well-being, and productivity.</p>

# %% [markdown]
# ### 3. What is the distribution of sleep hours among individuals?

# %%
plt.figure(figsize=(8,6))

plt.hist(
    df_new["sleep_hours"],
    bins=20,
    color="darkmagenta",
    edgecolor="black"
)

plt.title("Distribution of Sleep Hours Among Individuals")
plt.xlabel("Sleep Hours")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📊 Insight</h2
# <p>The majority of individuals sleep between 6–8 hours, followed by a notable group sleeping 4–6 hours. Fewer individuals sleep more than 8 hours, while very few experience extreme sleep deprivation of less than 4 hours, indicating that moderate sleep duration is most common but insufficient sleep is still prevalent.</p>

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">🔹2. Bivariate</h2>

# %% [markdown]
# ### 4. How does sleep duration vary between males and females, and what is the distribution of sleep hours within each gender group?

# %%
sns.violinplot(
    data=df_new,
    x="gender",
    y="sleep_hours_numeric",
    palette="PuRd",   
    inner="box"         
)
plt.title("Sleep Duration by Gender", fontsize=14, weight="bold")
plt.xlabel("Gender")
plt.ylabel("Sleep Duration")

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📊 Insight</h2
# <p>The distributions for Male and Female are almost identical in shape and spread.Most values cluster between 5 to 7 hours, suggesting similar sleep behavior across these groups.The inner box (median and IQR) for all three groups sits around ~6 hours.This indicates no major difference in central tendency by gender.</p>

# %% [markdown]
# ### 5. How do medical conditions affect sleep latency (time taken to fall asleep)?

# %%
sns.boxplot(
    x='medical_conditions',
    y="sleep_latency",
    data=df_new,color="darkorchid"
)

plt.title("Medical Conditions vs Sleep Latency")
plt.xlabel("Medical Conditions")
plt.ylabel("Sleep Latency (Numeric)")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📊 Insight</h2
# <p>Sleep latency is generally high across all groups.Medical conditions increase variability, but not necessarily the median delay.There may be hidden influencing variables beyond medical conditions.</p>

# %% [markdown]
# ### 6 Is there any relationship between breathing difficulty and restless legs among individuals?

# %%
df_br = pd.crosstab(
    df_new["breathing_difficulty"],
    df_new["restless_legs"]
)

df_long = df_br.reset_index().melt(
    id_vars="breathing_difficulty",
    var_name="restless_legs",
    value_name="count"
)
plt.figure(figsize=(7,5))

sns.barplot(
    data=df_long,
    x="breathing_difficulty",
    y="count",
    hue="restless_legs",palette="plasma"
)

plt.title("Breathing Difficulty vs Restless Legs")
plt.xticks(rotation=30, ha="right")
plt.legend(title="Restless Legs", bbox_to_anchor=(1.05, 1), loc="upper left")

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📊 Insight</h2
# <p>There is no strong linear or direct relationship between breathing difficulty and restless legs.Some patterns exist, but they are inconsistent across categories.This suggests other factors may play a bigger role.</p>

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">🔹3. Multivariate</h2>

# %% [markdown]
# ### 7. How do average sleep hours vary across BMI categories and age?

# %%
plt.figure(figsize=(8, 6))

sns.barplot(
    data=df_new,
    x="age",
    y="sleep_hours_numeric",
    hue="bmi_category",
    estimator="mean",palette="colorblind"
)

plt.title("Average Sleep Hours Across BMI Categories and Age Groups")
plt.xlabel("Age")
plt.ylabel("Average Sleep Hours")
plt.legend(title="BMI Category",bbox_to_anchor=(1.05, 1),
    loc="upper left")

plt.show()

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📊 Insight</h2
# <p>While BMI shows minor variation in sleep duration, age appears to be a stronger influencing factor. Underweight individuals generally sleep slightly longer, whereas overweight individuals tend to have reduced sleep, particularly among younger adults. However, overlapping variability indicates that sleep behavior is shaped by a combination of lifestyle and demographic factors rather than BMI alone.</p>

# %% [markdown]
# ### 8. Do medical conditions influence sleep behavior patterns?

# %%
sns.pairplot(
    df_new,
    vars=[
        "sleep_hours_numeric",
        "sleep_latency_numeric",
        "sleep_environment_comfort"
    ],
    hue="medical_conditions",
    diag_kind="kde",palette="Set1"
)

plt.show()

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📊 Insight</h2
# <p>The chart suggests that people with medical conditions (“Yes”) are more frequent in lower sleep quality patterns, especially longer sleep latency and lower comfort scores.</p>

# %% [markdown]
# ### 9. Is sleep duration related to body size (height and weight)?

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(
    data=df_new,
    x="height",
    y="weight",
    hue="sleep_hours_numeric",
    size="sleep_hours_numeric",palette="tab10"
    
)

plt.title("Height vs Weight by Sleep Hours")
plt.xlabel("Height")
plt.ylabel("Weight")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📊 Insight</h2
# <p>Body size (height/weight) varies independently of sleep hours in this visualization, while height shows only a modest relationship with weight.</p>

# %% [markdown]
# ### 10. How do sleep patterns (bedtime vs sleep hour) vary between weekdays and weekends?

# %%
weekday_data = df_new.groupby("bedtime_hour")["sleep_hours_numeric"].mean()
weekend_data = df_new.groupby("bedtime_weekend_hour")["sleep_hours_numeric"].mean()

# %%
plt.figure(figsize=(8,6))
plt.plot(weekday_data.index, weekday_data.values, marker='o', label="Weekdays",color="indigo")
plt.plot(weekend_data.index, weekend_data.values, marker='o', linestyle='--', label="Weekends",color="#EC7063")

plt.xticks(
    [21,23,25,27],
    ["Before 10 PM", "10 PM-12 AM", "12 AM-2 AM", "After 2 AM"],rotation=45
)

plt.xlabel("Bedtime")
plt.ylabel("Average Sleep Duration")
plt.title("Weekday vs Weekend Sleep Duration Trend")
plt.legend()  
plt.show()

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📊 Insight</h2
# <p>Both weekdays and weekends show the highest average sleep duration in the 12 AM–2 AM range.
# This suggests your body might naturally align with a slightly later sleep schedule.Sleeping before 10 PM results in the lowest average sleep duration for both groups.On weekends, you generally get more sleep than weekdays in earlier time slots (before midnight).
# However, during the peak window (12–2 AM), weekdays slightly exceed weekends, which is interesting and may reflect structured routines.Sleep duration drops noticeably after 2 AM for both weekdays and weekends.
# This implies that going too late negatively impacts total rest, even if you wake up later.</p>

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">🔹4.Interactive Visuals</h2>

# %% [markdown]
# ### 11. How are different side effect distributed across genders?

# %%
df_plot = pd.crosstab(df_sideeffects["gender"], df_sideeffects["sleep_sideeffects"]).reset_index()

# %%
df_long = df_plot.melt(id_vars="gender",
                       var_name="sleep_sideeffects",
                       value_name="count")
fig = px.bar(
    df_long,
    x="gender",
    y="count",
    color="sleep_sideeffects",
    barmode="stack",
    title="Distribution of Side Effects Across Genders",
    text_auto=True,color_discrete_sequence=px.colors.qualitative.Dark2)

fig.update_layout(
    xaxis_title="Gender",
    yaxis_title="Count",
    legend_title="Side Effects"
)

fig.show()

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📊 Insight</h2
# <p>Fatigue is the most common side effect for both males and females, making it the dominant issue across genders.Health issues and mood swings or irritability are also major contributors in both groups, indicating these are consistently high-impact side effects regardless of gender.The overall distribution suggests that side effects are fairly similar across genders, with no drastic differences in the top categories.</p>

# %% [markdown]
# ### 12. How are key sleep-related variables correlated with each other?

# %%
corr = df_new.corr(numeric_only=True)

fig = px.imshow(
    corr,
    text_auto=True,
    color_continuous_scale="OrRd"
)

fig.update_layout(
    title="Correlation Between Key Sleep-Related Variables",
    width=900,
    height=700
)

fig.show()

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">📊 Insight</h2
# <p>The analysis reveals that BMI is strongly driven by weight and height, while most sleep-related variables show weak relationships. However, a significant negative correlation between weekend wake time and sleep latency suggests that individuals who wake later on weekends tend to fall asleep faster, highlighting a potential behavioral sleep pattern.</p>

# %% [markdown]
# <div style="flex: 1; color: white;background-color:#0b1f3a; padding:25px; border-radius:10px;font-family:Arial;">
# <h2>5. Insight Generation and Report</h2>

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">🔍 Key Insights</h2>
# <ul style="font-size:16px; line-height:1.6;">
# <li>Most individuals in the dataset sleep within the 6–8 hour range, indicating a generally moderate but not optimal sleep pattern for everyone. However, a noticeable portion still falls below 6 hours, suggesting potential sleep deprivation concerns.</li>
# <li>Sleep latency shows a clear relationship with sleep duration — individuals who take longer to fall asleep tend to have reduced total sleep hours, highlighting sleep initiation as a critical factor affecting overall rest.</li>
# <li>Medical conditions (such as fatigue, mood swings, and health issues) are strongly associated with poorer sleep outcomes, including lower sleep duration and higher sleep latency. This indicates that health status plays a major role in sleep quality.</li>
# <li>Gender differences in sleep behavior are not highly significant, as both males and females show similar sleep duration distributions. This suggests gender is not a primary driver of sleep patterns in this dataset.</li>
# <li>A few anomalies were observed where individuals report high sleep hours but still experience fatigue or poor performance, indicating that sleep quality may be more important than sleep quantity alone.</li>
# <li>Sleep patterns appear to vary across lifestyle factors such as occupation and environment comfort, suggesting that daily routine and living conditions influence sleep behavior significantly.</li>
# </ul>

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">💡Recommendations</h2>
# <ul style="font-size:16px; line-height:1.6;">
# <li>Individuals reporting fatigue, mood swings, or health issues should be prioritized for further analysis, as these conditions are strongly linked with poor sleep quality. Early intervention may help improve overall well-being.</li>
# <li>Promote better sleep hygiene practices (regular sleep schedule, comfortable environment, reduced noise/light exposure) as environment comfort shows influence on sleep outcomes.</li>
# <li>Investigate cases where individuals report high sleep duration but still experience fatigue, as these may indicate underlying health issues or poor sleep efficiency.</li>

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">✅ Conclusion</h2>
#     <p style="font-size:16px; line-height:1.5;">
# The dataset shows that sleep behavior is primarily influenced by lifestyle and health conditions rather than gender alone. Sleep latency and medical conditions have a stronger impact on sleep quality than demographic factors.</P>

# %% [markdown]
# <div style="background: linear-gradient(to right, #eef2f3, #dfe9f3); padding:25px; border-radius:10px; font-family:Arial;">
#     <h2 style="color:#2c3e50;">🚀 Future Work</h2>
# <ul style="font-size:16px; line-height:1.6;">
# <li>Build a predictive model for sleep quality</li>
# <li>Develop an interactive dashboard</li>
# <li>Include more demographic and behavioral variables</li>
# </ul>
